# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhithanri123/Python-Mini-Project/blob/main/age%2Cheight%2Cweight_jpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ds = pd.read_csv('/content/drive/MyDrive/Credit_Card_Applications.csv')

# %%
ds
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1      15739548   0  22.67   7.000   2   8   4  0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# ..          ...  ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13   A14  Class
# ...

# %%
#find out the shape - Row size and column
ds.shape
# Out:
# (690, 16)

# %%
# Give the information realated to the Dataframe
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  690 non-null    int64
#  1   A1          690 non-null    int64
#  2   A2          690 non-null    float64
#  3   A3          690 non-null    float64
#  4   A4          690 non-null    int64
#  5   A5          690 non-null    int64
#  6   A6          690 non-null    int64
#  7   A7          690 non-null    float64
#  8   A8          690 non-null    int64
#  9   A9          690 non-null    int64
#  10  A10         690 non-null    int64
#  11  A11         690 non-null    int64
#  12  A12         690 non-null    int64
#  13  A13         690 non-null    int64
#  14  A14         690 non-null    int64
#  15  Class       690 non-null    int64
# dtypes: float64(3), int64(13)
# memory usage: 86.4 KB

# %%
# change the number of elements(visible in the code editor ouput)
pd.set_option('display.max_columns',10)
pd.set_option('display.max_rows',10)

# %%
#head extracts only 5 as default value
ds.head()
#head(n)- where it returns n number of values
ds.head(10)
# Out:
#    CustomerID  A1     A2      A3  A4  ...  A11  A12  A13   A14  Class
# 0    15776156   1  22.08  11.460   2  ...    1    2  100  1213      0
# 1    15739548   0  22.67   7.000   2  ...    0    2  160     1      0
# 2    15662854   0  29.58   1.750   1  ...    1    2  280     1      0
# 3    15687688   0  21.67  11.500   1  ...    1    2    0     1      1
# 4    15715750   1  20.17   8.170   2  ...    0    2   60   159      1
# 5    15571121   0  15.83   0.585   2  ...    0    2  100     1      1
# 6    15726466   1  17.42   6.500   2  ...    0    2   60   101      0
# 7    15660390   0  58.67   4.460   2  ...    0    2   43   561      1
# 8    15663942   1  27.83   1.000   1  ...    0    2  176   538      0
# 9    15638610   0  55.75   7.080   2  ...    1    2  100    51      0
#
# [10 rows x 16 columns]

# %%
ds.tail(10)
# Out:
#      CustomerID  A1     A2      A3  A4  ...  A11  A12  A13   A14  Class
# 680    15790689   1  21.17   0.000   2  ...    1    1    0     1      0
# 681    15665181   1  35.25  16.500   1  ...    0    2   80     1      0
# 682    15633608   0  22.92  11.585   2  ...    0    2   80  1350      1
# 683    15805261   0  48.17   1.335   2  ...    0    2    0   121      0
# 684    15740356   1  43.00   0.290   1  ...    0    2  100   376      1
# 685    15808223   1  31.57  10.500   2  ...    0    2    0     1      1
# 686    15769980   1  20.67   0.415   2  ...    0    2    0    45      0
# 687    15675450   0  18.83   9.540   2  ...    0    2  100     1      1
# 688    15776494   0  27.42  14.500   2  ...    0    2  120    12      1
# 689    15592412   1  41.00   0.040   2  ...    0    1  560     1      1
#
# [10 rows x 16 columns]

# %%
import random
age = []
height = []
weight = []
speed = []
for _ in range(100):
  age.append(random.randint(0,100))
  height.append(random.randint(0,100))
  weight.append(random.randint(0,100))
  speed.append(random.randint(0,100))

idata = {'Age':age,'Height':height,'Weight':weight,'Speed':speed}

# %%
idata
# Out:
# {'Age': [45,
#   87,
#   32,
#   56,
#   88,
#   72,
#   64,
#   29,
#   89,
#   90,
#   34,
#   74,
#   32,
#   50,
#   6,
#   66,
#   10,
#   49,
#   94,
#   35,
#   87,
#   87,
#   72,
#   68,
#   38,
#   41,
#   6,
#   82,
#   51,
#   51,
#   56,
#   35,
#   62,
#   51,
#   17,
#   9,
#   28,
#   14,
#   6,
#   25,
#   78,
#   42,
#   36,
#   22,
#   94,
#   76,
#   90,
#   42,
#   1,
#   84,
#   73,
#   1,
#   22,
#   10,
#   25,
#   81,
#   37,
#   39,
#   62,
#   15,
#   0,
#   86,
#   89,
#   24,
#   43,
#   33,
#   43,
#   42,
#   31,
#   16,
#   88,
#   90,
#   73,
#   88,
#   3,
#   46,
#   24,
#   50,
#   77,
#   8,
#   44,
#   31,
#   60,
#   35,
#   76,
#   99,
#   99,
#   3,
#   52,
#   64,
#   31,
#   77,
#   84,
#   50,
#   90,
#   47,
#   0,
#   44,
#   25,
#   28],
#  'Height': [37,
#   3,
#   58,
#   74,
#   11,
#   49,
#   40,
#   56,
#   35,
#   54,
#   11,
#   91,
#   54,
#   69,
#   46,
#   32,
#   39,
#   26,
#   40,
#   84,
#   85,
#   47,
#   45,
#   35,
# ...

# %%
df1 = pd.DataFrame (idata)

# %%
df1
# Out:
#     Age  Height  Weight  Speed
# 0    45      37      16      0
# 1    87       3      59     98
# 2    32      58      83     35
# 3    56      74      76     69
# 4    88      11      20     14
# ..  ...     ...     ...    ...
# 95   47      41      82     57
# 96    0      23      54     36
# 97   44      19      94     25
# 98   25      75      44     90
# 99   28      68      81     86
#
# [100 rows x 4 columns]

# %%
df1.describe()
# Out:
#               Age      Height      Weight       Speed
# count  100.000000  100.000000  100.000000  100.000000
# mean    49.110000   48.460000   50.760000   49.240000
# std     28.678255   27.991131   30.774553   29.276846
# min      0.000000    0.000000    1.000000    0.000000
# 25%     28.000000   26.000000   19.750000   24.500000
# 50%     45.500000   45.500000   52.000000   46.500000
# 75%     76.000000   72.000000   79.500000   73.250000
# max     99.000000  100.000000  100.000000   99.000000

# %%
df1[['Age','Height']]
# Out:
#     Age  Height
# 0    45      37
# 1    87       3
# 2    32      58
# 3    56      74
# 4    88      11
# ..  ...     ...
# 95   47      41
# 96    0      23
# 97   44      19
# 98   25      75
# 99   28      68
#
# [100 rows x 2 columns]

# %%
df1.loc[[0,3],['Age','Height']]
# Out:
#    Age  Height
# 0   45      37
# 3   56      74

# %%
df1[0::2]
# Out:
#     Age  Height  Weight  Speed
# 0    45      37      16      0
# 2    32      58      83     35
# 4    88      11      20     14
# 6    64      40      81     80
# 8    89      35      83     92
# ..  ...     ...     ...    ...
# 90   31      72       6     45
# 92   84      83       7     33
# 94   90      39      93      2
# 96    0      23      54     36
# 98   25      75      44     90
#
# [50 rows x 4 columns]

# %%
df1[0::2].describe()
# Out:
#              Age      Height      Weight      Speed
# count  50.000000   50.000000   50.000000  50.000000
# mean   49.340000   43.700000   49.660000  47.960000
# std    30.591856   27.571244   33.499686  31.675626
# min     0.000000    0.000000    3.000000   0.000000
# 25%    25.750000   21.500000   15.000000  15.750000
# 50%    44.500000   40.000000   50.500000  46.000000
# 75%    76.750000   64.500000   82.500000  77.500000
# max    99.000000  100.000000  100.000000  99.000000

# %%
df1.sort_index(ascending = True)
# Out:
#     Age  Height  Weight  Speed
# 0    45      37      16      0
# 1    87       3      59     98
# 2    32      58      83     35
# 3    56      74      76     69
# 4    88      11      20     14
# ..  ...     ...     ...    ...
# 95   47      41      82     57
# 96    0      23      54     36
# 97   44      19      94     25
# 98   25      75      44     90
# 99   28      68      81     86
#
# [100 rows x 4 columns]

# %%
# Filter
filter1 = df1['Weight'] > 50

# %%
df1[filter1]
# Out:
#     Age  Height  Weight  Speed
# 1    87       3      59     98
# 2    32      58      83     35
# 3    56      74      76     69
# 6    64      40      81     80
# 7    29      56      87     54
# ..  ...     ...     ...    ...
# 94   90      39      93      2
# 95   47      41      82     57
# 96    0      23      54     36
# 97   44      19      94     25
# 99   28      68      81     86
#
# [50 rows x 4 columns]

# %%
df1.loc[filter1]
# Out:
#     Age  Height  Weight  Speed
# 1    87       3      59     98
# 2    32      58      83     35
# 3    56      74      76     69
# 6    64      40      81     80
# 7    29      56      87     54
# ..  ...     ...     ...    ...
# 94   90      39      93      2
# 95   47      41      82     57
# 96    0      23      54     36
# 97   44      19      94     25
# 99   28      68      81     86
#
# [50 rows x 4 columns]

# %%
filter2 = df1['Age'] > 50

# %%
df1[filter1 & filter2]
# Out:
#     Age  Height  Weight  Speed
# 1    87       3      59     98
# 3    56      74      76     69
# 6    64      40      81     80
# 8    89      35      83     92
# 20   87      85      94     67
# ..  ...     ...     ...    ...
# 84   76      45      93      1
# 85   99      47      74     58
# 86   99       6      81      9
# 88   52      97      89     53
# 94   90      39      93      2
#
# [25 rows x 4 columns]

# %%
exmpl_name={'Name':['Nikhitha','Vyshu','Satya'],
            'Age':[10,22,19],
            'Height':[180,158,178]}

# %%
df = pd.DataFrame(exmpl_name)

# %%
df
# Out:
#        Name  Age  Height
# 0  Nikhitha   10     180
# 1     Vyshu   22     158
# 2     Satya   19     178

# %%
ds
# Out:
#      CustomerID  A1     A2      A3  A4  ...  A11  A12  A13   A14  Class
# 0      15776156   1  22.08  11.460   2  ...    1    2  100  1213      0
# 1      15739548   0  22.67   7.000   2  ...    0    2  160     1      0
# 2      15662854   0  29.58   1.750   1  ...    1    2  280     1      0
# 3      15687688   0  21.67  11.500   1  ...    1    2    0     1      1
# 4      15715750   1  20.17   8.170   2  ...    0    2   60   159      1
# ..          ...  ..    ...     ...  ..  ...  ...  ...  ...   ...    ...
# 685    15808223   1  31.57  10.500   2  ...    0    2    0     1      1
# 686    15769980   1  20.67   0.415   2  ...    0    2    0    45      0
# 687    15675450   0  18.83   9.540   2  ...    0    2  100     1      1
# 688    15776494   0  27.42  14.500   2  ...    0    2  120    12      1
# 689    15592412   1  41.00   0.040   2  ...    0    1  560     1      1
#
# [690 rows x 16 columns]
