# %%
import random

# %%
a1=[]
a2=[]
a3=[]
a4=[]
a5=[]

# %%
for _ in range (1000):
    a1.append (random.randint(0,100))
    a2.append (random.randint(50,70))
    a3.append (random.randint(10,20))
    a4.append (random.randint(5,10))
    a5.append (random.randint(20,80))

# %%
df = {
    'grade': a1,
    'weight' : a2,
    'friends' : a3,
    'cousins':a4,
    'projects' : a5
}

# %%
import pandas as pd

# %%
df1 = pd. DataFrame(df)

# %%
df1
# Out:
#      grade  weight  friends  cousins  projects
# 0       58      67       17        9        26
# 1       15      57       16        7        24
# 2       88      57       18        9        22
# 3        2      64       14        5        63
# 4       31      66       20       10        50
# ..     ...     ...      ...      ...       ...
# 995     91      67       15        6        56
# 996     13      65       15        9        46
# 997     10      57       20        5        27
# 998     95      66       18       10        35
# 999     37      59       10        6        71
#
# [1000 rows x 5 columns]

# %%
df1.describe()
# Out:
#              grade       weight      friends      cousins     projects
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     49.440000    60.251000    15.064000     7.513000    49.519000
# std      29.320063     5.971906     3.142257     1.706676    17.623457
# min       0.000000    50.000000    10.000000     5.000000    20.000000
# 25%      23.000000    55.000000    12.000000     6.000000    35.000000
# 50%      52.000000    61.000000    15.000000     7.500000    49.000000
# 75%      73.000000    65.000000    18.000000     9.000000    65.000000
# max     100.000000    70.000000    20.000000    10.000000    80.000000

# %%
df1
# Out:
#      grade  weight  friends  cousins  projects
# 0       58      67       17        9        26
# 1       15      57       16        7        24
# 2       88      57       18        9        22
# 3        2      64       14        5        63
# 4       31      66       20       10        50
# ..     ...     ...      ...      ...       ...
# 995     91      67       15        6        56
# 996     13      65       15        9        46
# 997     10      57       20        5        27
# 998     95      66       18       10        35
# 999     37      59       10        6        71
#
# [1000 rows x 5 columns]

# %%
df1['grade'].count()
# Out:
# np.int64(1000)

# %%
df1['grade'].count
# Out:
# <bound method Series.count of 0      58
# 1      15
# 2      88
# 3       2
# 4      31
#        ..
# 995    91
# 996    13
# 997    10
# 998    95
# 999    37
# Name: grade, Length: 1000, dtype: int64>

# %%
friend15=df1['friends']>15

# %%
df1[friend15]
# Out:
#      grade  weight  friends  cousins  projects
# 0       58      67       17        9        26
# 1       15      57       16        7        24
# 2       88      57       18        9        22
# 4       31      66       20       10        50
# 5       65      70       19       10        77
# ..     ...     ...      ...      ...       ...
# 991     55      55       20        5        26
# 993     37      65       17        9        74
# 994     92      50       20        8        49
# 997     10      57       20        5        27
# 998     95      66       18       10        35
#
# [456 rows x 5 columns]

# %%
grade50=df1['grade']>50

# %%
friend18=df1['friends']>18

# %%
df1[friend18]
# Out:
#      grade  weight  friends  cousins  projects
# 4       31      66       20       10        50
# 5       65      70       19       10        77
# 7       17      66       19        7        24
# 9       49      59       20       10        73
# 17      96      63       19        8        77
# ..     ...     ...      ...      ...       ...
# 976      1      50       19        5        78
# 983     77      53       19        6        52
# 991     55      55       20        5        26
# 994     92      50       20        8        49
# 997     10      57       20        5        27
#
# [198 rows x 5 columns]

# %%
grade98=df1['grade']>98

# %%
df1[grade98]
# Out:
#      grade  weight  friends  cousins  projects
# 61      99      50       18        8        73
# 82     100      59       16        7        66
# 84      99      66       17        6        78
# 125     99      57       11       10        56
# 272    100      65       14        8        23
# 281    100      68       17        7        50
# 427    100      58       13       10        62
# 442    100      51       18        6        20
# 552     99      66       12        9        45
# 647    100      66       20        6        29
# 685    100      62       17        9        74
# 744    100      65       10        6        71
# 905     99      63       15        9        28
# 908    100      60       16        6        30
# 987    100      54       17        6        62

# %%
df1[friend18 & grade98]['friends']
# Out:
# 647    20
# Name: friends, dtype: int64

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\niki\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (3.9.4)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: packaging>=20.0 in c:\users\niki\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\niki\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (4.55.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\niki\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\niki\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\niki\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\niki\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\niki\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: pillow>=8 in c:\users\niki\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\niki\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: numpy>=1.23 in c:\users\niki\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\niki\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in c:\users\niki\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# WARNING: You are using pip version 22.0.4; however, version 25.0 is available.
# You should consider upgrading via the 'C:\Users\NIKI\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
df1[friend15 & grade50].plot()
# Out:
# <Axes: >

# %%
df1[friend15 & grade50].plot(x='grade',y='projects',kind='bar')
# Out:
# <Axes: xlabel='grade'>

# %%
df1[friend15 & grade50].plot(x='grade',y='projects',kind='area')
# Out:
# <Axes: xlabel='grade'>

# %%
df1[friend15 & grade50].plot(x=['grade','friends'] ,y=['projects', 'weight'],kind='scatter',title='sample graph')
plt. xlabel('X Axis')
plt.ylabel('Y Axis')
plt.legend('Test Data')
plt.show()

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\niki\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (3.9.4)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\niki\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\niki\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\niki\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\niki\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\niki\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\niki\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (4.55.8)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\niki\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.23 in c:\users\niki\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\niki\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\niki\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\niki\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in c:\users\niki\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# WARNING: You are using pip version 22.0.4; however, version 25.0 is available.
# You should consider upgrading via the 'C:\Users\NIKI\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
fdf = df1[friend15 & grade50]

# %%
fdf
# Out:
#      grade  weight  friends  cousins  projects
# 0       58      67       17        9        26
# 2       88      57       18        9        22
# 5       65      70       19       10        77
# 16      62      55       16        8        70
# 17      96      63       19        8        77
# ..     ...     ...      ...      ...       ...
# 983     77      53       19        6        52
# 987    100      54       17        6        62
# 991     55      55       20        5        26
# 994     92      50       20        8        49
# 998     95      66       18       10        35
#
# [239 rows x 5 columns]

# %%
df1.to_csv('C:/Users/NIKI/Desktop/New folder/data.csv')
